# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/pest-clef-2026/PestCLEF-2026_test.json
# /kaggle/input/pest-clef-2026/PestCLEF-2026_dev.json
# /kaggle/input/pest-clef-2026/PestCLEF-2026_train.json

# %%
import json
import pandas as pd
import os

# 1. Define file paths (adjust if your Kaggle dataset path differs)
test_json_path = '/kaggle/input/pest-clef-2026/PestCLEF-2026_test.json'
# Assuming text files are in a folder named 'text' or similar
text_folder_path = '/kaggle/input/pest-clef-2026/text/' 

# 2. Load the test JSON data
print("Loading test data...")
with open(test_json_path, 'r', encoding='utf-8') as f:
    test_data = json.load(f)

predictions_for_submission = []

# 3. Iterate through each document in the test set
print(f"Processing {len(test_data)} test documents...")
for doc in test_data:
    doc_id = doc['doc_id']
    
    # Optional: Load the actual text for the document if your extraction logic needs it
    text_file_path = os.path.join(text_folder_path, f"{doc_id}.txt")
    doc_text = ""
    if os.path.exists(text_file_path):
        with open(text_file_path, 'r', encoding='utf-8') as tf:
            doc_text = tf.read()
    
    # -----------------------------------------------------------------
    # INSERT YOUR EXTRACTION LOGIC HERE
    # -----------------------------------------------------------------
    # For now, we initialize an empty knowledge graph to ensure the 
    # submission pipeline runs perfectly without formatting errors.
    predicted_kg = []
    
    # Example of how you would append an extracted relationship:
    # predicted_kg.append({
    #     "predicate": "Located_in",
    #     "subject": "ToBRFV",
    #     "object": "tomato crops"
    # })
    # -----------------------------------------------------------------
    
    # The competition requires the knowledge_graph column to be a serialized JSON string
    predictions_for_submission.append({
        "doc_id": doc_id,
        "knowledge_graph": json.dumps(predicted_kg)
    })

# 4. Format and save the final submission DataFrame
submission_df = pd.DataFrame(predictions_for_submission)

# Ensure exact column order: 'doc_id', 'knowledge_graph'
submission_df = submission_df[['doc_id', 'knowledge_graph']]

submission_df.to_csv('submission.csv', index=False)
print("submission.csv created successfully! Ready to submit.")

# Display the first few rows to verify the format
print(submission_df.head())
# Out:
# Loading test data...
# Processing 82 test documents...
# submission.csv created successfully! Ready to submit.
#    doc_id knowledge_graph
# 0  104657              []
# 1  107116              []
# 2   97985              []
# 3  103005              []
# 4  107265              []
